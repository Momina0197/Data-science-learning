# %%
import pandas as pd

df = pd.read_csv("DATA.csv")

# %%
df.columns

# %%
list(df.iloc[10])

# %% [markdown]
# ###### Filtering Gender where Name

# %%
df[(df["gender"] == "Male") & (df["name"] == "Mike")]

# %% [markdown]
# ###### Filtering Rows where Gender is Male and Female

# %%
df[~df["gender"].isin(["Female", "Male"])]

# %% [markdown]
# ###### Updating Merry's Gender

# %%
df.loc[df["name"] =="Merry", "gender"] ="Male"

# %%
df[df["name"] == "Merry"]

# %% [markdown]
# ###### Converting all rows where gender into upper case

# %%
df["gender"] = df["gender"].str.upper()

# %%
df["gender"]

# %% [markdown]
# ###### Dropping row

# %%
df = df.drop(998)

# %%
df.tail()

# %% [markdown]
# ###### Displaying the values of each gender

# %%
df["gender"].value_counts()
